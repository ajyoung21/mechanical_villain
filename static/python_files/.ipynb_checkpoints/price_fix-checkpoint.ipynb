# %%
import pandas as pd

# %%
df = pd.read_csv("../data/island_info.csv")
df
# Out:
#      Unnamed: 0               Island_Name  Acreage                   Country  \
# 0             0       Island of Patroklos      643                    Greece
# 1             1            Rangyai Island      110                  Thailand
# 2             2               Pumpkin Key       26  United States of America
# 3             3        Spectabilis Island      460                   Bahamas
# 4             4                  Cave Cay      222                   Bahamas
# ..          ...                       ...      ...                       ...
# 679         679    Water Island Peninsula        2  United States of America
# 680         680      Private Island Exuma       46                   Bahamas
# 681         681             Pebble Island    26247          Falkland Islands
# 682         682  Long Caye Private Island       40                    Belize
# 683         683                 Funk Caye        3                    Belize
#
#       latitude  longitude Large Acreage Ocean Island Income Potential  \
# 0    37.653723  23.949079           yes          yes              yes
# 1     7.954390  98.447306           yes          yes              yes
# 2    24.713197 -81.554253           yes          yes              yes
# 3    24.358032 -76.582153           yes          yes              yes
# 4    23.901611 -76.263142           yes          yes              yes
# ..         ...        ...           ...          ...              ...
# 679  18.318585 -64.958120            no          yes              yes
# 680  24.184307 -76.441174           yes          yes              yes
# 681 -51.286789 -59.652042           yes          yes              yes
# 682  16.489920 -88.214336           yes          yes              yes
# 683  16.550108 -88.084820            no          yes               no
#
#     Mainland Power  ... Airstrip or Fly-in Income Producing Lake Island  \
# 0              yes  ...                 no               no          no
# 1               no  ...                 no               no          no
# 2               no  ...                 no               no          no
# 3               no  ...                 no               no          no
# 4               no  ...                 no               no          no
# ..             ...  ...                ...              ...         ...
# 679             no  ...                 no               no          no
# 680             no  ...                 no               no          no
# 681             no  ...                yes              yes          no
# 682             no  ...                 no               no          no
# 683             no  ...                 no               no          no
#
#     Seasonal Historic River Island Mainland Lot    nearest_city city_distance  \
# 0         no       no           no           no   Palaiá Fókaia          4.58
# 1         no       no           no           no     Ban Ko Kaeo          3.69
# 2         no       no           no           no      Cudjoe Key          4.54
# 3         no       no           no           no   Arthur’s Town         60.10
# 4         no       no           no           no     George Town         40.22
# ..       ...      ...          ...          ...             ...           ...
# 679       no       no           no           no    Saint Paul’s        153.16
# 680       no       no           no           no   Arthur’s Town         57.11
# 681       no      yes           no           no  Puerto Deseado        371.38
# 682       no       no           no           no       Placencia         10.22
# 683       no       no           no           no       Placencia         18.82
#
#            price
# 0            NaN
# 1    160000000.0
# 2     95000000.0
# 3     62000000.0
# 4     60000000.0
# ..           ...
# 679          NaN
# 680          NaN
# 681          NaN
# 682          NaN
# 683          NaN
#
# [684 rows x 22 columns]

# %%
price_list = df["price"].tolist()
prices = []
for item in price_list:
    check = item[0:3]
    if check == "USD":
        price = item[3:]
    else:
        price = "NA"
    prices.append(price)

df2 = df.drop(columns=["price"])
df2["price"]=prices
df2.to_csv("../data/island_info.csv", index=False)

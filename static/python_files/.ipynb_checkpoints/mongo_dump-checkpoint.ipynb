# %%
# Import Dependancies
import pandas as pd
import pymongo
import ast
import json

# %%
# Set-up Mongo client
conn = 'mongodb+srv://Taylor:Tay22894@islandcluster-or9h1.mongodb.net/test?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)

# %%
# Connect to a DataBase
db = client.island_base

# %%
# Read in the CSV
df = pd.read_csv("../data/island_final_price.csv")
df = df.set_index("Island_Name")

# Convert to JSON
json_object = df.to_json(orient='index')

# Get it ready for the dump
json_object = json.loads(json_object)
json_object
# Out:
# {'Rangyai Island': {'Acreage': 110,
#   'Country': 'Thailand',
#   'latitude': 7.95439,
#   'longitude': 98.447306,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Ban Ko Kaeo',
#   'city_distance': 3.69,
#   'price': 160000000.0,
#   'predicted': 'no'},
#  'Pumpkin Key': {'Acreage': 26,
#   'Country': 'United States of America',
#   'latitude': 24.713197,
#   'longitude': -81.5542528,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Cudjoe Key',
#   'city_distance': 4.54,
#   'price': 95000000.0,
#   'predicted': 'no'},
#  'Spectabilis Island': {'Acreage': 460,
#   'Country': 'Bahamas',
#   'latitude': 24.3580321,
#   'longitude': -76.5821528,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Arthur’s Town',
#   'city_distance': 60.1,
#   'price': 62000000.0,
#   'predicted': 'no'},
#  'Cave Cay': {'Acreage': 222,
#   'Country': 'Bahamas',
#   'latitude': 23.9016110903,
#   'longitude': -76.2631419954,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'George Town',
#   'city_distance': 40.22,
#   'price': 60000000.0,
#   'predicted': 'no'},
#  'Nengo Nengo Atoll': {'Acreage': 2223,
#   'Country': 'France',
#   'latitude': -18.7531020179,
#   'longitude': -141.8078964233,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 1,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Avarua',
#   'city_distance': 1178.3,
#   'price': 55778670.24,
#   'predicted': 'no'},
#  'Darby Island': {'Acreage': 554,
#   'Country': 'Bahamas',
#   'latitude': 23.8495955,
#   'longitude': -76.2276337,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 1,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 1,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'George Town',
#   'city_distance': 36.18,
#   'price': 46000000.0,
#   'predicted': 'no'},
#  'Dulichium Island': {'Acreage': 1335,
#   'Country': 'Greece',
#   'latitude': 38.4142572771,
#   'longitude': 21.0917757513,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Astakós',
#   'city_distance': 8.4,
#   'price': 44622936.19,
#   'predicted': 'no'},
#  'Motu Tane': {'Acreage': 10,
#   'Country': 'France',
#   'latitude': -16.4490481,
#   'longitude': -151.7630533,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Avarua',
#   'city_distance': 618.38,
#   'price': 39000000.0,
#   'predicted': 'no'},
#  'Organica Beach': {'Acreage': 1492,
#   'Country': 'Panama',
#   'latitude': 8.3091734472,
#   'longitude': -78.9702341663,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'San Miguel',
#   'city_distance': 10.45,
#   'price': 38000000.0,
#   'predicted': 'no'},
#  'Little Ragged Island': {'Acreage': 700,
#   'Country': 'Bahamas',
#   'latitude': 22.1649094,
#   'longitude': -75.7051647,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Gibara',
#   'city_distance': 77.87,
#   'price': 35000000.0,
#   'predicted': 'no'},
#  'Big Grand Cay Archipelago': {'Acreage': 213,
#   'Country': 'Bahamas',
#   'latitude': 27.2215783788,
#   'longitude': -78.3162854992,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'High Rock',
#   'city_distance': 42.32,
#   'price': 29000000.0,
#   'predicted': 'no'},
#  'Frozen Cay and Alder Cay': {'Acreage': 84,
#   'Country': 'Bahamas',
#   'latitude': 25.5436805377,
#   'longitude': -77.7136802673,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'San Andros',
#   'city_distance': 39.08,
#   'price': 29000000.0,
#   'predicted': 'no'},
#  'Bird Cay': {'Acreage': 250,
#   'Country': 'Bahamas',
#   'latitude': 25.4003556,
#   'longitude': -77.815285,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 1,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'San Andros',
#   'city_distance': 27.33,
#   'price': 26000000.0,
#   'predicted': 'no'},
#  'Kanacea Island': {'Acreage': 3085,
#   'Country': 'Fiji',
#   'latitude': -17.263613,
#   'longitude': -179.151735,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Lau Province',
#   'city_distance': 69.2,
#   'price': 26000000.0,
#   'predicted': 'no'},
#  'Nusa Riro': {'Acreage': 22,
#   'Country': 'Solomon Islands',
#   'latitude': -8.2876215274,
#   'longitude': 157.1317541843,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 1,
#   'Seasonal': 0,
#   'Historic': 1,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Gizo',
#   'city_distance': 23.57,
#   'price': 25000000.0,
#   'predicted': 'no'},
#  'Matana South Seas Plantation': {'Acreage': 806,
#   'Country': 'Fiji',
#   'latitude': -17.2605876886,
#   'longitude': 179.3499754546,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Cakaudrove Province',
#   'city_distance': 41.27,
#   'price': 25000000.0,
#   'predicted': 'no'},
#  'Lera Cay': {'Acreage': 80,
#   'Country': 'Bahamas',
#   'latitude': 24.7615833,
#   'longitude': -76.2681944444,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Arthur’s Town',
#   'city_distance': 38.67,
#   'price': 24000000.0,
#   'predicted': 'no'},
#  'Leaf Cay Private Residences': {'Acreage': 15,
#   'Country': 'Bahamas',
#   'latitude': 24.150151,
#   'longitude': -76.473169,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 1,
#   'Income Producing': 1,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Arthur’s Town',
#   'city_distance': 60.08,
#   'price': 24000000.0,
#   'predicted': 'no'},
#  'Captiva Key': {'Acreage': 13,
#   'Country': 'United States of America',
#   'latitude': 26.5093874628,
#   'longitude': -82.1847380174,
#   'Large Acreage': 0,
#   'Ocean Island': 0,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Saint James City',
#   'city_distance': 6.62,
#   'price': 22000000.0,
#   'predicted': 'no'},
#  'The Plantation': {'Acreage': 495,
#   'Country': 'Belize',
#   'latitude': 16.5879279985,
#   'longitude': -88.3626546043,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Placencia',
#   'city_distance': 5.1,
#   'price': 21000000.0,
#   'predicted': 'no'},
#  'Guafo Island': {'Acreage': 49422,
#   'Country': 'Chile',
#   'latitude': -43.5930556,
#   'longitude': -74.7136111,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Quellón',
#   'city_distance': 64.14,
#   'price': 20000000.0,
#   'predicted': 'no'},
#  'Ile de Caille': {'Acreage': 400,
#   'Country': 'Grenada',
#   'latitude': 12.287246,
#   'longitude': -61.583143,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Sauteurs',
#   'city_distance': 6.08,
#   'price': 20000000.0,
#   'predicted': 'no'},
#  'Jwycesska Island': {'Acreage': 351,
#   'Country': 'Bahamas',
#   'latitude': 27.1206248,
#   'longitude': -78.0837346,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'High Rock',
#   'city_distance': 37.27,
#   'price': 19000000.0,
#   'predicted': 'no'},
#  'Violin Island': {'Acreage': 321,
#   'Country': 'Mexico',
#   'latitude': 18.8098598959,
#   'longitude': -88.0876632577,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Calderitas',
#   'city_distance': 20.71,
#   'price': 18000000.0,
#   'predicted': 'no'},
#  'Little Hawkins Island': {'Acreage': 3,
#   'Country': 'United States of America',
#   'latitude': 31.197381,
#   'longitude': -81.394983,
#   'Large Acreage': 0,
#   'Ocean Island': 0,
#   'Income Potential': 1,
#   'Mainland Power': 1,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 1,
#   'River Island': 1,
#   'Mainland Lot': 0,
#   'nearest_city': 'Saint Simon Mills',
#   'city_distance': 1.98,
#   'price': 17800000.0,
#   'predicted': 'no'},
#  'Frozen Cay': {'Acreage': 40,
#   'Country': 'Bahamas',
#   'latitude': 25.5485843364,
#   'longitude': -77.7130723926,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'San Andros',
#   'city_distance': 39.39,
#   'price': 17000000.0,
#   'predicted': 'no'},
#  'St Thomas': {'Acreage': 300,
#   'Country': 'Greece',
#   'latitude': 37.809623,
#   'longitude': 23.247124,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Ágioi Theódoroi',
#   'city_distance': 9.95,
#   'price': 16733601.07,
#   'predicted': 'no'},
#  'World Island Project (D98)': {'Acreage': 12,
#   'Country': 'United Arab Emirates',
#   'latitude': 25.2310608076,
#   'longitude': 55.167477417,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 1,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Dubai',
#   'city_distance': 13.84,
#   'price': 16000000.0,
#   'predicted': 'no'},
#  'Charles Island': {'Acreage': 55,
#   'Country': 'Bahamas',
#   'latitude': 25.540893,
#   'longitude': -76.748171,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Spanish Wells',
#   'city_distance': 1.08,
#   'price': 16000000.0,
#   'predicted': 'no'},
#  'Palm Island': {'Acreage': 4,
#   'Country': 'United States of America',
#   'latitude': 24.7124487588,
#   'longitude': -81.1068604749,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Marathon',
#   'city_distance': 1.04,
#   'price': 15500000.0,
#   'predicted': 'no'},
#  "Terra's Key": {'Acreage': 16,
#   'Country': 'United States of America',
#   'latitude': 24.8926886853,
#   'longitude': -80.6589413042,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 1,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Islamorada',
#   'city_distance': 2.93,
#   'price': 15000000.0,
#   'predicted': 'no'},
#  'East Sister Rock': {'Acreage': 1,
#   'Country': 'United States of America',
#   'latitude': 24.6872480459,
#   'longitude': -81.0745817086,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Marathon',
#   'city_distance': 2.08,
#   'price': 15000000.0,
#   'predicted': 'no'},
#  'Alder Cay': {'Acreage': 43,
#   'Country': 'Bahamas',
#   'latitude': 25.5368382,
#   'longitude': -77.7144461,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'San Andros',
#   'city_distance': 38.66,
#   'price': 15000000.0,
#   'predicted': 'no'},
#  'Cebaco Island': {'Acreage': 7410,
#   'Country': 'Panama',
#   'latitude': 7.5527201,
#   'longitude': -81.0865035,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 1,
#   'nearest_city': 'Mariato District',
#   'city_distance': 10.34,
#   'price': 15000000.0,
#   'predicted': 'no'},
#  'Big Sampson Cay': {'Acreage': 121,
#   'Country': 'Bahamas',
#   'latitude': 24.2122708,
#   'longitude': -76.4772748,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 1,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Arthur’s Town',
#   'city_distance': 58.08,
#   'price': 14500000.0,
#   'predicted': 'no'},
#  'Elizabeth Island Property': {'Acreage': 38,
#   'Country': 'Bahamas',
#   'latitude': 23.503712257,
#   'longitude': -75.7202272084,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'George Town',
#   'city_distance': 4.3,
#   'price': 14000000.0,
#   'predicted': 'no'},
#  'False Caye': {'Acreage': 60,
#   'Country': 'Belize',
#   'latitude': 16.602023452,
#   'longitude': -88.3388570125,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Placencia',
#   'city_distance': 6.34,
#   'price': 12000000.0,
#   'predicted': 'no'},
#  'Nananu-I-Cake': {'Acreage': 600,
#   'Country': 'Fiji',
#   'latitude': -17.3183977277,
#   'longitude': 178.2317482593,
#   'Large Acreage': 0,
#   'Ocean Island': 0,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Ra Province',
#   'city_distance': 13.26,
#   'price': 12000000.0,
#   'predicted': 'no'},
#  'An Island Within An Island': {'Acreage': 14,
#   'Country': 'Bahamas',
#   'latitude': 26.5045364099,
#   'longitude': -78.6561535788,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Lucaya',
#   'city_distance': 2.09,
#   'price': 12000000.0,
#   'predicted': 'no'},
#  'Saddleback Cay': {'Acreage': 47,
#   'Country': 'Bahamas',
#   'latitude': 24.6541089605,
#   'longitude': -76.8109130859,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Nassau',
#   'city_distance': 43.5,
#   'price': 11800000.0,
#   'predicted': 'no'},
#  'Pepin Island': {'Acreage': 1280,
#   'Country': 'New Zealand',
#   'latitude': -41.1507105,
#   'longitude': 173.4264652,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Nelson',
#   'city_distance': 11.12,
#   'price': 11467068.01,
#   'predicted': 'no'},
#  'The Duke Group Archipelago': {'Acreage': 3300,
#   'Country': 'Australia',
#   'latitude': -21.983476,
#   'longitude': 150.16094,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 1,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Sarina',
#   'city_distance': 72.07,
#   'price': 11379153.39,
#   'predicted': 'no'},
#  'Spalathronisi Island': {'Acreage': 26,
#   'Country': 'Greece',
#   'latitude': 40.0208364399,
#   'longitude': 23.8075646641,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Néos Marmarás',
#   'city_distance': 5.36,
#   'price': 11155734.05,
#   'predicted': 'no'},
#  'Nakacha Huraa Lagoon': {'Acreage': 29,
#   'Country': 'Maldives',
#   'latitude': 4.3442396846,
#   'longitude': 73.3906427719,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Hulhumale',
#   'city_distance': 13.78,
#   'price': 11000000.0,
#   'predicted': 'no'},
#  'Isla Puerco': {'Acreage': 160,
#   'Country': 'Panama',
#   'latitude': 8.3674816118,
#   'longitude': -78.8078927355,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'San Miguel',
#   'city_distance': 10.77,
#   'price': 11000000.0,
#   'predicted': 'no'},
#  'Batchawana Island': {'Acreage': 5200,
#   'Country': 'Canada',
#   'latitude': 46.8925425758,
#   'longitude': -84.5187070205,
#   'Large Acreage': 1,
#   'Ocean Island': 0,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 1,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Sault Ste. Marie',
#   'city_distance': 27.41,
#   'price': 10972379.87,
#   'predicted': 'no'},
#  'Kuramaadhoo Island': {'Acreage': 44,
#   'Country': 'Maldives',
#   'latitude': 5.873270623,
#   'longitude': 73.1435554921,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Ugoofaaru',
#   'city_distance': 16.18,
#   'price': 10765283.36,
#   'predicted': 'no'},
#  'Keraamithaa Island': {'Acreage': 103,
#   'Country': 'Maldives',
#   'latitude': 0.390701,
#   'longitude': 73.012837,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Thinadhoo',
#   'city_distance': 9.71,
#   'price': 10765283.36,
#   'predicted': 'no'},
#  'Deer Cay': {'Acreage': 603,
#   'Country': 'Belize',
#   'latitude': 18.0980190964,
#   'longitude': -87.9565386788,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'San Pedro',
#   'city_distance': 12.59,
#   'price': 10500000.0,
#   'predicted': 'no'},
#  'Thompson Island': {'Acreage': 5,
#   'Country': 'United States of America',
#   'latitude': 24.5641647716,
#   'longitude': -81.7492341844,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Stock Island',
#   'city_distance': 0.71,
#   'price': 10495000.0,
#   'predicted': 'no'},
#  'Tavernier Key': {'Acreage': 31,
#   'Country': 'United States of America',
#   'latitude': 24.9970503466,
#   'longitude': -80.5021861967,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Tavernier',
#   'city_distance': 1.28,
#   'price': 10149000.0,
#   'predicted': 'no'},
#  'Toad Hall Estate': {'Acreage': 6,
#   'Country': 'United Kingdom',
#   'latitude': 18.4303327,
#   'longitude': -64.4435806,
#   'Large Acreage': 0,
#   'Ocean Island': 0,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 1,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Saint Paul’s',
#   'city_distance': 127.21,
#   'price': 10000000.0,
#   'predicted': 'no'},
#  'Belle Island & Cubbage Island': {'Acreage': 264,
#   'Country': 'United States of America',
#   'latitude': 31.7638299905,
#   'longitude': -81.2206780566,
#   'Large Acreage': 1,
#   'Ocean Island': 0,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 1,
#   'River Island': 1,
#   'Mainland Lot': 0,
#   'nearest_city': 'Midway',
#   'city_distance': 12.67,
#   'price': 10000000.0,
#   'predicted': 'no'},
#  'Young Island Resort': {'Acreage': 13,
#   'Country': 'SVG',
#   'latitude': 13.1310220238,
#   'longitude': -61.20260967,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 1,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Kingstown',
#   'city_distance': 2.37,
#   'price': 10000000.0,
#   'predicted': 'no'},
#  'Water Caye': {'Acreage': 567,
#   'Country': 'Belize',
#   'latitude': 17.384237,
#   'longitude': -88.064037,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Belize City',
#   'city_distance': 11.87,
#   'price': 10000000.0,
#   'predicted': 'no'},
#  'Lataro Island': {'Acreage': 719,
#   'Country': 'Vanuatu',
#   'latitude': -15.26504,
#   'longitude': 167.191537,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 1,
#   'Income Producing': 1,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 1,
#   'nearest_city': 'Port-Olry',
#   'city_distance': 17.35,
#   'price': 9995000.0,
#   'predicted': 'no'},
#  'Great Sale Cay': {'Acreage': 370,
#   'Country': 'Bahamas',
#   'latitude': 26.9966296,
#   'longitude': -78.2105857,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'High Rock',
#   'city_distance': 27.04,
#   'price': 9900000.0,
#   'predicted': 'no'},
#  'Lumber Cay': {'Acreage': 30,
#   'Country': 'Bahamas',
#   'latitude': 24.1617749947,
#   'longitude': -76.4300155867,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Arthur’s Town',
#   'city_distance': 57.37,
#   'price': 9400000.0,
#   'predicted': 'no'},
#  'Jim Cay': {'Acreage': 8,
#   'Country': 'Bahamas',
#   'latitude': 23.883476165,
#   'longitude': -76.2560270322,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'George Town',
#   'city_distance': 39.06,
#   'price': 9000000.0,
#   'predicted': 'no'},
#  'Sandy Island': {'Acreage': 20,
#   'Country': 'Grenada',
#   'latitude': 12.2220101,
#   'longitude': -61.5858804,
#   'Large Acreage': 0,
#   'Ocean Island': 0,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Sauteurs',
#   'city_distance': 3.61,
#   'price': 9000000.0,
#   'predicted': 'no'},
#  'Isla Di Yerba': {'Acreage': 8,
#   'Country': 'Curacao',
#   'latitude': 12.0796735907,
#   'longitude': -68.8451996306,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 1,
#   'nearest_city': 'Puerto Cumarebo',
#   'city_distance': 53.5,
#   'price': 8800000.0,
#   'predicted': 'no'},
#  'Trump Island': {'Acreage': 29,
#   'Country': 'United States of America',
#   'latitude': 48.5044389,
#   'longitude': -122.8386889,
#   'Large Acreage': 1,
#   'Ocean Island': 0,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 1,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Friday Harbor',
#   'city_distance': 8.42,
#   'price': 8750000.0,
#   'predicted': 'no'},
#  'Leaf Cay': {'Acreage': 30,
#   'Country': 'Bahamas',
#   'latitude': 23.7861,
#   'longitude': -76.1271,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'George Town',
#   'city_distance': 28.5,
#   'price': 8500000.0,
#   'predicted': 'no'},
#  'Roberts Cay': {'Acreage': 20,
#   'Country': 'Bahamas',
#   'latitude': 24.7966302484,
#   'longitude': -76.8317274233,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Nassau',
#   'city_distance': 36.79,
#   'price': 8000000.0,
#   'predicted': 'no'},
#  'Sipson Island': {'Acreage': 25,
#   'Country': 'United States of America',
#   'latitude': 41.7365537162,
#   'longitude': -69.963220454,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 1,
#   'River Island': 0,
#   'Mainland Lot': 1,
#   'nearest_city': 'Chatham',
#   'city_distance': 3.77,
#   'price': 7985000.0,
#   'predicted': 'no'},
#  'Devils Cay': {'Acreage': 117,
#   'Country': 'Bahamas',
#   'latitude': 25.600664,
#   'longitude': -77.728615,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'San Andros',
#   'city_distance': 42.0,
#   'price': 7950000.0,
#   'predicted': 'no'},
#  'Katitche Point Greathouse': {'Acreage': 1,
#   'Country': 'United Kingdom',
#   'latitude': 18.47188,
#   'longitude': -64.414659289,
#   'Large Acreage': 0,
#   'Ocean Island': 0,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 1,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Saint Paul’s',
#   'city_distance': 127.27,
#   'price': 7950000.0,
#   'predicted': 'no'},
#  'Powell Cay': {'Acreage': 294,
#   'Country': 'Bahamas',
#   'latitude': 26.9081888,
#   'longitude': -77.4773674,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Cooper’s Town',
#   'city_distance': 3.29,
#   'price': 7895000.0,
#   'predicted': 'no'},
#  'Woodmere Island': {'Acreage': 5,
#   'Country': 'Canada',
#   'latitude': 45.143841,
#   'longitude': -79.583031,
#   'Large Acreage': 0,
#   'Ocean Island': 0,
#   'Income Potential': 1,
#   'Mainland Power': 1,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 1,
#   'Seasonal': 1,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Bracebridge',
#   'city_distance': 15.08,
#   'price': 7895000.0,
#   'predicted': 'no'},
#  'Kaashihulhudhoo Island': {'Acreage': 38,
#   'Country': 'Maldives',
#   'latitude': 0.488143835,
#   'longitude': 72.9946242967,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Thinadhoo',
#   'city_distance': 2.95,
#   'price': 7809013.83,
#   'predicted': 'no'},
#  'Horse Island': {'Acreage': 157,
#   'Country': 'Ireland',
#   'latitude': 51.5163046,
#   'longitude': -9.4680023,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 1,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Skibbereen',
#   'city_distance': 8.96,
#   'price': 7530120.48,
#   'predicted': 'no'},
#  'Adavaci Island': {'Acreage': 102,
#   'Country': 'Fiji',
#   'latitude': -17.2000521923,
#   'longitude': -179.0071173279,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Lau Province',
#   'city_distance': 70.85,
#   'price': 7500000.0,
#   'predicted': 'no'},
#  'Petit Trou Peninsula': {'Acreage': 50,
#   'Country': 'Grenada',
#   'latitude': 12.0250083197,
#   'longitude': -61.6594451666,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Saint David’s',
#   'city_distance': 1.77,
#   'price': 7500000.0,
#   'predicted': 'no'},
#  "Frenchman's Caye": {'Acreage': 200,
#   'Country': 'Belize',
#   'latitude': 17.5728442022,
#   'longitude': -88.075202851,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Belize City',
#   'city_distance': 9.52,
#   'price': 7500000.0,
#   'predicted': 'no'},
#  'Parida Island': {'Acreage': 217,
#   'Country': 'Panama',
#   'latitude': 8.1294648092,
#   'longitude': -82.332038738,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 1,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Pedregal',
#   'city_distance': 17.79,
#   'price': 7500000.0,
#   'predicted': 'no'},
#  'Aese Island': {'Acreage': 1690,
#   'Country': 'Vanuatu',
#   'latitude': -15.4316954,
#   'longitude': 167.2491365,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Luganville',
#   'city_distance': 8.4,
#   'price': 7500000.0,
#   'predicted': 'no'},
#  'Sand Dollar Cay': {'Acreage': 24,
#   'Country': 'Bahamas',
#   'latitude': 25.5700075897,
#   'longitude': -77.7232934329,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'San Andros',
#   'city_distance': 40.32,
#   'price': 7200000.0,
#   'predicted': 'no'},
#  'Motu Rauoro': {'Acreage': 18,
#   'Country': 'France',
#   'latitude': -16.5728975861,
#   'longitude': -151.4435714607,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Avarua',
#   'city_distance': 631.61,
#   'price': 7137688.53,
#   'predicted': 'no'},
#  "Sawyer's Cay": {'Acreage': 6,
#   'Country': 'Bahamas',
#   'latitude': 25.539214,
#   'longitude': -76.805107,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Spanish Wells',
#   'city_distance': 2.62,
#   'price': 7050000.0,
#   'predicted': 'no'},
#  'Bonefish Cay 135-acres': {'Acreage': 14,
#   'Country': 'Bahamas',
#   'latitude': 26.8903572761,
#   'longitude': -77.4512103635,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Cooper’s Town',
#   'city_distance': 3.93,
#   'price': 7000000.0,
#   'predicted': 'no'},
#  '40-acre Beachfront Property on Ambergris Caye': {'Acreage': 40,
#   'Country': 'Belize',
#   'latitude': 18.001592,
#   'longitude': -87.9432837,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 1,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'San Pedro',
#   'city_distance': 6.1,
#   'price': 6999500.0,
#   'predicted': 'no'},
#  'Bird Island': {'Acreage': 51,
#   'Country': 'United States of America',
#   'latitude': 28.8975881215,
#   'longitude': -81.8518781868,
#   'Large Acreage': 1,
#   'Ocean Island': 0,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 1,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Fruitland Park',
#   'city_distance': 4.14,
#   'price': 6700000.0,
#   'predicted': 'no'},
#  'Vargas Island Lot': {'Acreage': 65,
#   'Country': 'Canada',
#   'latitude': 49.2029000552,
#   'longitude': -126.0364707787,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 1,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Tofino',
#   'city_distance': 6.77,
#   'price': 6600000.0,
#   'predicted': 'no'},
#  'Motu Moie': {'Acreage': 20,
#   'Country': 'France',
#   'latitude': -16.5581434289,
#   'longitude': -151.5119237745,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Avarua',
#   'city_distance': 628.31,
#   'price': 6500000.0,
#   'predicted': 'no'},
#  'Tiger Point': {'Acreage': 359,
#   'Country': 'Belize',
#   'latitude': 17.2495959796,
#   'longitude': -88.337132009,
#   'Large Acreage': 0,
#   'Ocean Island': 0,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Belize City',
#   'city_distance': 19.57,
#   'price': 6400000.0,
#   'predicted': 'no'},
#  'Nail Bay Land': {'Acreage': 60,
#   'Country': 'United Kingdom',
#   'latitude': 18.4939059,
#   'longitude': -64.4022877,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Saint Paul’s',
#   'city_distance': 127.49,
#   'price': 6200000.0,
#   'predicted': 'no'},
#  'Toberua Island Resort': {'Acreage': 5,
#   'Country': 'Fiji',
#   'latitude': -17.9749062,
#   'longitude': 178.7047,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 1,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Tailevu Province',
#   'city_distance': 16.64,
#   'price': 6200000.0,
#   'predicted': 'no'},
#  'Kelefesia Island': {'Acreage': 32,
#   'Country': 'Tonga',
#   'latitude': -20.5015930155,
#   'longitude': -174.7357548994,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Kolonga',
#   'city_distance': 48.6,
#   'price': 6000000.0,
#   'predicted': 'no'},
#  'Janoyoy Island': {'Acreage': 4,
#   'Country': 'Philippines',
#   'latitude': 9.7546852,
#   'longitude': 126.1312853,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Union',
#   'city_distance': 1.44,
#   'price': 5600000.0,
#   'predicted': 'no'},
#  'Pierre Island': {'Acreage': 16,
#   'Country': 'Bahamas',
#   'latitude': 25.556148,
#   'longitude': -76.659508,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Dunmore Town',
#   'city_distance': 4.0,
#   'price': 5495000.0,
#   'predicted': 'no'},
#  'Stroggilo Island': {'Acreage': 54,
#   'Country': 'Greece',
#   'latitude': 37.3727430833,
#   'longitude': 26.71626091,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 1,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Skála',
#   'city_distance': 10.14,
#   'price': 5020080.32,
#   'predicted': 'no'},
#  'Fishermans Caye': {'Acreage': 42,
#   'Country': 'Belize',
#   'latitude': 16.6722409838,
#   'longitude': -88.1898094065,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Placencia',
#   'city_distance': 16.0,
#   'price': 4995000.0,
#   'predicted': 'no'},
#  'Tivi Island': {'Acreage': 150,
#   'Country': 'Fiji',
#   'latitude': -16.2720355323,
#   'longitude': 179.468791869,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Labasa',
#   'city_distance': 13.11,
#   'price': 4995000.0,
#   'predicted': 'no'},
#  'La Patella': {'Acreage': 1,
#   'Country': 'Bahamas',
#   'latitude': 25.0462947121,
#   'longitude': -77.5001288578,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Nassau',
#   'city_distance': 9.87,
#   'price': 4950000.0,
#   'predicted': 'no'},
#  'North Saddle Caye': {'Acreage': 4,
#   'Country': 'Belize',
#   'latitude': 16.6932120436,
#   'longitude': -88.1710331005,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
# ...
#   'Mainland Lot': 0,
#   'nearest_city': 'Belize City',
#   'city_distance': 10.32,
#   'price': 6144973.5,
#   'predicted': 'yes'},
#  'Tikina-i-ra Island': {'Acreage': 10233,
#   'Country': 'Fiji',
#   'latitude': -16.7688839088,
#   'longitude': 178.4899028045,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Bua Province',
#   'city_distance': 17.77,
#   'price': 3893946.5,
#   'predicted': 'yes'},
#  'Sear Island': {'Acreage': 28,
#   'Country': 'Canada',
#   'latitude': 49.1468942514,
#   'longitude': -123.6915773285,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 1,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Cedar',
#   'city_distance': 7.58,
#   'price': 3865413.0,
#   'predicted': 'yes'},
#  'Jupiter Island': {'Acreage': 642,
#   'Country': 'Ecuador',
#   'latitude': 0.432841,
#   'longitude': -80.05711,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 1,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Muisne',
#   'city_distance': 12.61,
#   'price': 17106512.0,
#   'predicted': 'yes'},
#  '2620': {'Acreage': 1350,
#   'Country': 'Greece',
#   'latitude': 38.0693095526,
#   'longitude': 19.0253207125,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Lixoúri',
#   'city_distance': 77.26,
#   'price': 44847212.0,
#   'predicted': 'yes'},
#  'Tovu Island': {'Acreage': 180,
#   'Country': 'Fiji',
#   'latitude': -17.3461080877,
#   'longitude': 178.0588478545,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Ra Province',
#   'city_distance': 12.79,
#   'price': 5870850.0,
#   'predicted': 'yes'},
#  'Sindiro Island': {'Acreage': 220,
#   'Country': 'Uganda',
#   'latitude': 0.1592298241,
#   'longitude': 33.1371184609,
#   'Large Acreage': 1,
#   'Ocean Island': 0,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 1,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Njeru',
#   'city_distance': 19.73,
#   'price': 12838716.0,
#   'predicted': 'yes'},
#  'Crawl Caye (Belize City)': {'Acreage': 48,
#   'Country': 'Belize',
#   'latitude': 17.5779361382,
#   'longitude': -87.7944514415,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'San Pedro',
#   'city_distance': 25.94,
#   'price': 3786128.5,
#   'predicted': 'yes'},
#  'Little Bay Estate': {'Acreage': 7,
#   'Country': 'United Kingdom',
#   'latitude': 18.4915555118,
#   'longitude': -64.3649942659,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Saint Paul’s',
#   'city_distance': 125.42,
#   'price': 4342106.5,
#   'predicted': 'yes'},
#  '26-Acre Island in Blue Ground Range': {'Acreage': 3,
#   'Country': 'Belize',
#   'latitude': 16.8148581541,
#   'longitude': -88.1509961265,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Dangriga',
#   'city_distance': 12.0,
#   'price': 2635352.0,
#   'predicted': 'yes'},
#  'Wadigi Island': {'Acreage': 0,
#   'Country': 'Fiji',
#   'latitude': -17.7178813686,
#   'longitude': 177.1479932258,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Nadi',
#   'city_distance': 18.6,
#   'price': 2158595.75,
#   'predicted': 'yes'},
#  'The Balam Escape': {'Acreage': 9500,
#   'Country': 'Belize',
#   'latitude': 17.9859084262,
#   'longitude': -88.1981396393,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'San Pedro',
#   'city_distance': 16.01,
#   'price': 14405556.0,
#   'predicted': 'yes'},
#  '42-Acre Private Island West of Placencia Village': {'Acreage': 42,
#   'Country': 'Belize',
#   'latitude': 16.5151528447,
#   'longitude': -88.3769658831,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Placencia',
#   'city_distance': 0.7,
#   'price': 4457960.0,
#   'predicted': 'yes'},
#  'Mauger Caye': {'Acreage': 7,
#   'Country': 'Belize',
#   'latitude': 17.607045928,
#   'longitude': -87.7720123042,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'San Pedro',
#   'city_distance': 24.87,
#   'price': 415909.8125,
#   'predicted': 'yes'},
#  'Pair of Fiji Islands': {'Acreage': 25,
#   'Country': 'Fiji',
#   'latitude': -17.1121121,
#   'longitude': 177.2469064,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Lautoka',
#   'city_distance': 37.37,
#   'price': 4130622.25,
#   'predicted': 'yes'},
#  'Gibraleon Island': {'Acreage': 227,
#   'Country': 'Panama',
#   'latitude': 8.5168638913,
#   'longitude': -79.045165847,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Distrito de Balboa',
#   'city_distance': 4.64,
#   'price': 9139742.0,
#   'predicted': 'yes'},
#  'Wailagilala Island': {'Acreage': 113,
#   'Country': 'Fiji',
#   'latitude': -16.7489479768,
#   'longitude': -179.1031979566,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Cakaudrove Province',
#   'city_distance': 98.11,
#   'price': 19021140.0,
#   'predicted': 'yes'},
#  'Pine Island, Vermont': {'Acreage': 23,
#   'Country': 'United States of America',
#   'latitude': 44.8086821435,
#   'longitude': -71.868528165,
#   'Large Acreage': 1,
#   'Ocean Island': 0,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 1,
#   'Seasonal': 1,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 1,
#   'nearest_city': 'Essex County',
#   'city_distance': 8.57,
#   'price': 563920.625,
#   'predicted': 'yes'},
#  'Denarau Peninsula': {'Acreage': 1,
#   'Country': 'Australia',
#   'latitude': -17.7637127962,
#   'longitude': 177.3853343601,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Nadi',
#   'city_distance': 3.39,
#   'price': 3720501.25,
#   'predicted': 'yes'},
#  'Laguna Azul': {'Acreage': 2,
#   'Country': 'Panama',
#   'latitude': 9.18880359,
#   'longitude': -82.1029002248,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 1,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Isla Bastimentos',
#   'city_distance': 7.96,
#   'price': 2407947.5,
#   'predicted': 'yes'},
#  'Jewel Caye': {'Acreage': 2,
#   'Country': 'Belize',
#   'latitude': 16.7907892217,
#   'longitude': -88.1564832494,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 1,
#   'nearest_city': 'Dangriga',
#   'city_distance': 13.36,
#   'price': 2558597.0,
#   'predicted': 'yes'},
#  'Reef Islands': {'Acreage': 237,
#   'Country': 'Vanuatu',
#   'latitude': -13.6211228716,
#   'longitude': 167.5276564646,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Sola',
#   'city_distance': 17.69,
#   'price': 6573458.0,
#   'predicted': 'yes'},
#  'Elizabeth Island': {'Acreage': 65,
#   'Country': 'Australia',
#   'latitude': -38.4162228,
#   'longitude': 145.3689712,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Bass Coast',
#   'city_distance': 7.0,
#   'price': 1816714.5,
#   'predicted': 'yes'},
#  'Crawl Caye (Placencia)': {'Acreage': 55,
#   'Country': 'Belize',
#   'latitude': 16.5991452018,
#   'longitude': -88.2157391037,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Placencia',
#   'city_distance': 11.58,
#   'price': 3786128.5,
#   'predicted': 'yes'},
#  'Thatch Cay': {'Acreage': 230,
#   'Country': 'United States of America',
#   'latitude': 18.3584973755,
#   'longitude': -64.8572876508,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Saint Paul’s',
#   'city_distance': 148.33,
#   'price': 19248824.0,
#   'predicted': 'yes'},
#  'Lenur Island': {'Acreage': 84,
#   'Country': 'Vanuatu',
#   'latitude': -16.5152455605,
#   'longitude': 167.5947246243,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Norsup',
#   'city_distance': 33.73,
#   'price': 859385.0,
#   'predicted': 'yes'},
#  'French Bay Property': {'Acreage': 130,
#   'Country': 'United States of America',
#   'latitude': 18.3154661978,
#   'longitude': -64.9049521821,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Saint Paul’s',
#   'city_distance': 149.89,
#   'price': 18542384.0,
#   'predicted': 'yes'},
#  'Water Island Peninsula': {'Acreage': 2,
#   'Country': 'United States of America',
#   'latitude': 18.3185849443,
#   'longitude': -64.9581197023,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Saint Paul’s',
#   'city_distance': 153.16,
#   'price': 4286123.5,
#   'predicted': 'yes'},
#  'Private Island Exuma': {'Acreage': 46,
#   'Country': 'Bahamas',
#   'latitude': 24.1843070982,
#   'longitude': -76.4411735762,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Arthur’s Town',
#   'city_distance': 57.11,
#   'price': 11925144.0,
#   'predicted': 'yes'},
#  'Pebble Island': {'Acreage': 26247,
#   'Country': 'Falkland Islands',
#   'latitude': -51.2867890996,
#   'longitude': -59.6520421703,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 1,
#   'Income Producing': 1,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 1,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Puerto Deseado',
#   'city_distance': 371.38,
#   'price': 21182944.0,
#   'predicted': 'yes'},
#  'Long Caye Private Island': {'Acreage': 40,
#   'Country': 'Belize',
#   'latitude': 16.4899200177,
#   'longitude': -88.2143360301,
#   'Large Acreage': 1,
#   'Ocean Island': 1,
#   'Income Potential': 1,
#   'Mainland Power': 0,
#   'Islands with Beaches': 0,
#   'Turn Key': 1,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Placencia',
#   'city_distance': 10.22,
#   'price': 7773700.5,
#   'predicted': 'yes'},
#  'Funk Caye': {'Acreage': 3,
#   'Country': 'Belize',
#   'latitude': 16.5501081179,
#   'longitude': -88.0848204607,
#   'Large Acreage': 0,
#   'Ocean Island': 1,
#   'Income Potential': 0,
#   'Mainland Power': 0,
#   'Islands with Beaches': 1,
#   'Turn Key': 0,
#   'Airstrip or Fly-in': 0,
#   'Income Producing': 0,
#   'Lake Island': 0,
#   'Seasonal': 0,
#   'Historic': 0,
#   'River Island': 0,
#   'Mainland Lot': 0,
#   'nearest_city': 'Placencia',
#   'city_distance': 18.82,
#   'price': 314097.0,
#   'predicted': 'yes'}}

# %%
# Insert dictionary into mongo
db.island_base.insert_one(json_object)

# %%
# Read in the CSV
df = pd.read_csv('../data/merged_countries.csv')
df = df.set_index("Country")

# Convert to JSON
json_object = df.to_json(orient='index')

# Get it ready for the dump
json_object = json.loads(json_object)
json_object
# Out:
# {'Antigua': {'Homicide Rate': 0.0,
#   'CPI Score 2018': 0.0,
#   'Standard error': 0.0},
#  'Argentina': {'Homicide Rate': 6.2,
#   'CPI Score 2018': 60.0,
#   'Standard error': 2.7},
#  'Australia': {'Homicide Rate': 1.1,
#   'CPI Score 2018': 23.0,
#   'Standard error': 1.27},
#  'Bahamas': {'Homicide Rate': 29.7,
#   'CPI Score 2018': 35.0,
#   'Standard error': 5.39},
#  'Belize': {'Homicide Rate': 29.4,
#   'CPI Score 2018': 71.0,
#   'Standard error': 0.0},
#  'Brazil': {'Homicide Rate': 31.3,
#   'CPI Score 2018': 65.0,
#   'Standard error': 4.05},
#  'Canada': {'Homicide Rate': 1.5,
#   'CPI Score 2018': 19.0,
#   'Standard error': 2.16},
#  'Chile': {'Homicide Rate': 4.4,
#   'CPI Score 2018': 33.0,
#   'Standard error': 1.88},
#  'Costa Rica': {'Homicide Rate': 10.2,
#   'CPI Score 2018': 44.0,
#   'Standard error': 3.65},
#  'Croatia': {'Homicide Rate': 1.0,
#   'CPI Score 2018': 52.0,
#   'Standard error': 2.77},
#  'Curacao': {'Homicide Rate': 0.0,
#   'CPI Score 2018': 0.0,
#   'Standard error': 0.0},
#  'Ecuador': {'Homicide Rate': 9.3,
#   'CPI Score 2018': 66.0,
#   'Standard error': 3.46},
#  'Estonia': {'Homicide Rate': 3.7,
#   'CPI Score 2018': 27.0,
#   'Standard error': 1.44},
#  'Falkland Islands': {'Homicide Rate': 0.0,
#   'CPI Score 2018': 0.0,
#   'Standard error': 0.0},
#  'Fiji': {'Homicide Rate': 2.5, 'CPI Score 2018': 60.0, 'Standard error': 0.0},
#  'Finland': {'Homicide Rate': 1.3,
#   'CPI Score 2018': 15.0,
#   'Standard error': 2.74},
#  'France': {'Homicide Rate': 0.9,
#   'CPI Score 2018': 28.0,
#   'Standard error': 1.17},
#  'Greece': {'Homicide Rate': 1.1,
#   'CPI Score 2018': 55.0,
#   'Standard error': 2.51},
#  'Grenada': {'Homicide Rate': 6.3,
#   'CPI Score 2018': 48.0,
#   'Standard error': 3.0},
#  'Honduras': {'Homicide Rate': 55.5,
#   'CPI Score 2018': 71.0,
#   'Standard error': 2.42},
#  'Iceland': {'Homicide Rate': 1.2,
#   'CPI Score 2018': 24.0,
#   'Standard error': 4.33},
#  'Indonesia': {'Homicide Rate': 4.5,
#   'CPI Score 2018': 62.0,
#   'Standard error': 3.35},
#  'Ireland': {'Homicide Rate': 0.8,
#   'CPI Score 2018': 27.0,
#   'Standard error': 3.25},
#  'Italy': {'Homicide Rate': 0.8,
#   'CPI Score 2018': 48.0,
#   'Standard error': 3.29},
#  'Japan': {'Homicide Rate': 0.3,
#   'CPI Score 2018': 27.0,
#   'Standard error': 2.85},
#  'Kenya': {'Homicide Rate': 5.3,
#   'CPI Score 2018': 73.0,
#   'Standard error': 1.82},
#  'Madagascar': {'Homicide Rate': 6.9,
#   'CPI Score 2018': 75.0,
#   'Standard error': 2.64},
#  'Maldives': {'Homicide Rate': 3.4,
#   'CPI Score 2018': 69.0,
#   'Standard error': 2.24},
#  'Mexico': {'Homicide Rate': 16.9,
#   'CPI Score 2018': 72.0,
#   'Standard error': 1.83},
#  'New Zealand': {'Homicide Rate': 1.1,
#   'CPI Score 2018': 13.0,
#   'Standard error': 2.44},
#  'Nicaragua': {'Homicide Rate': 13.9,
#   'CPI Score 2018': 75.0,
#   'Standard error': 1.13},
#  'Palau': {'Homicide Rate': 0.0, 'CPI Score 2018': 0.0, 'Standard error': 0.0},
#  'Panama': {'Homicide Rate': 20.5,
#   'CPI Score 2018': 63.0,
#   'Standard error': 1.76},
#  'Papua New Guinea': {'Homicide Rate': 10.2,
#   'CPI Score 2018': 72.0,
#   'Standard error': 2.47},
#  'Philippines': {'Homicide Rate': 14.8,
#   'CPI Score 2018': 64.0,
#   'Standard error': 1.55},
#  'Poland': {'Homicide Rate': 0.9,
#   'CPI Score 2018': 40.0,
#   'Standard error': 1.69},
#  'SVG': {'Homicide Rate': 0.0, 'CPI Score 2018': 0.0, 'Standard error': 0.0},
#  'Seychelles': {'Homicide Rate': 9.9,
#   'CPI Score 2018': 34.0,
#   'Standard error': 3.08},
#  'Solomon Islands': {'Homicide Rate': 4.3,
#   'CPI Score 2018': 56.0,
#   'Standard error': 7.38},
#  'Thailand': {'Homicide Rate': 5.0,
#   'CPI Score 2018': 64.0,
#   'Standard error': 2.08},
#  'Tonga': {'Homicide Rate': 4.6,
#   'CPI Score 2018': 69.0,
#   'Standard error': None},
#  'Turks and Caicos': {'Homicide Rate': 0.0,
#   'CPI Score 2018': 0.0,
#   'Standard error': 0.0},
#  'Uganda': {'Homicide Rate': 12.6,
#   'CPI Score 2018': 74.0,
#   'Standard error': 2.13},
#  'United Arab Emirates': {'Homicide Rate': 3.8,
#   'CPI Score 2018': 30.0,
#   'Standard error': 4.56},
#  'United Kingdom': {'Homicide Rate': 1.3,
#   'CPI Score 2018': 20.0,
#   'Standard error': 2.03},
#  'United States of America': {'Homicide Rate': 6.5,
#   'CPI Score 2018': 29.0,
#   'Standard error': 3.25},
#  'Vanuatu': {'Homicide Rate': 2.5,
#   'CPI Score 2018': 54.0,
#   'Standard error': 5.97}}

# %%
# Insert dictionary into mongo
db.island_base.insert_one(json_object)

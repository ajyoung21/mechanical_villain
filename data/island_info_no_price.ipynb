# %%
import pandas as pd
from sklearn.svm import SVC

# %%
df = pd.read_csv("../static/data/island_info.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
no_price_df = df.dropna()
no_price_df.head(50)
# Out:
#                      Island_Name  Acreage            continent  \
# 0                 Rangyai Island      110                 Asia
# 1             Spectabilis Island      460        North America
# 2                       Cave Cay      222        North America
# 3              Nengo Nengo Atoll     2223               Europe
# 4                  Kandoo Island       42                 Asia
# 5        Vadinolhu Island Resort       19        North America
# 6        Serenity Beaches Resort        8  South Pacific Ocean
# 7                Igoigori Island      150              Oceania
# 8               Ngerbelas Island       21              Oceania
# 9               Big Scrub Island      170               Europe
# 10                   Lovango Cay        5        North America
# 11           Tojo Una Una Island     3089                 Asia
# 12                 Ginger Island      258               Europe
# 13              Praia do Algodão       29        South America
# ...

# %%
no_price_df = no_price_df.groupby(["Island_Name"]).sum()
no_price_df = no_price_df.reset_index()
no_price_df["Island_Name"].count()
# Out:
# 259

# %%
df.head(5)
# Out:
#           Island_Name  Acreage      continent   Country   latitude  \
# 0      Rangyai Island      110           Asia  Thailand   7.954390
# 1  Spectabilis Island      460  North America   Bahamas  24.358032
# 2            Cave Cay      222  North America   Bahamas  23.901611
# 3   Nengo Nengo Atoll     2223         Europe    France -18.753102
# 4       Kandoo Island       42           Asia  Maldives   5.852108
#
#     longitude               price Large Acreage Ocean Island Income Potential  \
# 0   98.447306           160000000           yes          yes              yes
# 1  -76.582153            62000000           yes          yes              yes
# 2  -76.263142            60000000           yes          yes              yes
# 3 -141.807896            55778670           yes          yes              yes
# 4   73.336561  Price Upon Request           yes          yes              yes
#
#   Mainland Power Islands with Beaches Turn Key Airstrip or Fly-in  \
# ...

# %%
# no_price_df = pd.DataFrame(np.arange(12).reshape(3, 4),
#                   columns=['A', 'B', 'C', 'D'])
# no_price_df

# %%
no_price_df.drop(index='Price Upon Request ')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-f8dc0c641a5b> in <module>
# ----> 1 no_price_df.drop(index='Price Upon Request ')
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...
